# %% [markdown]
# # day1 sandbox notebook
#
# ## puzzle:
# You're standing in a room with "digitization quarantine" written in LEDs along one wall. The only door is locked, but it includes a small interface. "Restricted Area - Strictly No Digitized Users Allowed."
#
# It goes on to explain that you may only leave by solving a captcha to prove you're not a human. Apparently, you only get one millisecond to solve the captcha: too fast for a normal human, but it feels like hours to you.
#
# The captcha requires you to review a sequence of digits (your puzzle input) and find the sum of all digits that match the next digit in the list. The list is circular, so the digit after the last digit is the first digit in the list.
#
# For example:
#
# 1122 produces a sum of 3 (1 + 2) because the first digit (1) matches the second digit and the third digit (2) matches the fourth digit.
# 1111 produces 4 because each digit (all 1) matches the next.
# 1234 produces 0 because no digit matches the next.
# 91212129 produces 9 because the only digit that matches the next one is the last digit, 9.
# What is the solution to your captcha?
#
# ## captcha puzzle
# ...

# %%
puzzle = '...'

# %%
puzzle
# Out:
# '...'

# %%
puzzle[-2]
# Out:
# '8'

# %%
firstdigit = puzzle[0]
prevdigit = ''
cumm_sum = 0
pos = 0
for currdigit in puzzle:
    # iterate over digits in string
    if currdigit == prevdigit:
        # found a winner, add the prevdigit to the sum
        cumm_sum = cumm_sum + int(prevdigit)
        print('found match at pos', pos, 'digit: ', currdigit, 'new cumm_sum: ', cumm_sum)
    prevdigit = currdigit
    pos = pos + 1
# check if the last digit matches the first (circular)
if puzzle[-1] == puzzle[0]:
    cumm_sum = cumm_sum + int(puzzle[-1])
    print('last digit matches first, cumm_sum now', cumm_sum)
print('cumm_sum:', cumm_sum)
# Out:
# found match at pos 3 digit:  9 new cumm_sum:  9
# found match at pos 5 digit:  7 new cumm_sum:  16
# found match at pos 7 digit:  4 new cumm_sum:  20
# found match at pos 29 digit:  3 new cumm_sum:  23
# found match at pos 31 digit:  8 new cumm_sum:  31
# found match at pos 33 digit:  5 new cumm_sum:  36
# found match at pos 36 digit:  9 new cumm_sum:  45
# found match at pos 49 digit:  3 new cumm_sum:  48
# found match at pos 57 digit:  9 new cumm_sum:  57
# found match at pos 83 digit:  4 new cumm_sum:  61
# found match at pos 88 digit:  3 new cumm_sum:  64
# found match at pos 95 digit:  6 new cumm_sum:  70
# found match at pos 112 digit:  7 new cumm_sum:  77
# found match at pos 118 digit:  4 new cumm_sum:  81
# found match at pos 119 digit:  4 new cumm_sum:  85
# found match at pos 128 digit:  8 new cumm_sum:  93
# found match at pos 139 digit:  9 new cumm_sum:  102
# found match at pos 141 digit:  2 new cumm_sum:  104
# found match at pos 144 digit:  1 new cumm_sum:  105
# ...

# %% [markdown]
# # answer submitted and accepted
#
# That's the right answer! You are one gold star closer to debugging the printer. [Return to Day 1]
